# %% [markdown]
# # TUGAS 1
#
# Mengukur jarak (dissimilarity)
# 1. Ambil data dari Kaggle atau GitHub
# 2. Ukur jarak
# d(1,2), d(1,3), d(1,4) dari data tersebut

# %%
#import library
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statistics as st
from scipy import stats

url="https://raw.githubusercontent.com/MeAdila/dataset/main/gender_classification_v7.csv"

al=pd.read_csv(url)
al
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %% [markdown]
# Kategorical

# %%
# mengetahui jumlah kolom
jumlah_kolom = al.shape[1]
jumlah_kolom
# Out:
# 8

# %%
# tampilan untuk dataset yang akan diambil
pd.set_option('display.max_columns', jumlah_kolom)
pd.set_option('display.max_rows', jumlah_kolom)
# menampilkan hasil data
al.columns
# Out:
# Index(['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
#        'nose_long', 'lips_thin', 'distance_nose_to_lip_long', 'gender'],
#       dtype='object')

# %%
al[["long_hair","lips_thin", "gender"]].head(5)
# Out:
#    long_hair  lips_thin  gender
# 0          1          1    Male
# 1          0          1  Female
# 2          0          1    Male
# 3          0          1    Male
# 4          1          0  Female

# %% [markdown]
# Mengubah data menjadi Binary

# %%
# kode data gender
data_cherbourg = "Male"
data_southampton = "Female"

# nilai binary
nilai_satu = 1
nilai_nol = 0

def ubah_biner(gender):
    return nilai_satu if gender == data_southampton else nilai_nol

# %%
# Update nilai gender
al["gender"] = al["gender"].apply(ubah_biner)

# %%
al[["long_hair","lips_thin", "gender"]].head(5)
# Out:
#    long_hair  lips_thin  gender
# 0          1          1       0
# 1          0          1       1
# 2          0          1       0
# 3          0          1       0
# 4          1          0       1

# %%
# CONSTAN VARIABLE
DECREMENT_BY_ONE = 1
INCREMENT_BY_ONE = 1

CONTINGENCY_TABLE_VALUE = {
    "q" : (1,1),
    "r" : (1,0),
    "s" : (0,1),
    "t" : (0,0),
}

# %%
def get_series(al, idx, series):
    return al.loc[(idx), series]

# %%
def get_dissimilarity_dataset(al, series_index = [], series = []):
    first_series = get_series(al, series_index[0], series)
    second_series = get_series(al, series_index[1], series)
    dataset = pd.concat([first_series,second_series],axis=1)
    return dataset.T

# %%
get_dissimilarity_dataset(al, [1,2], ["long_hair","lips_thin"]).T
# Out:
#              1    2
# long_hair  0.0  0.0
# lips_thin  1.0  1.0

# %%
al.loc[0:5, ["lips_thin", "gender"]]
# Out:
#    lips_thin  gender
# 0          1       0
# 1          1       1
# 2          1       0
# 3          1       0
# 4          0       1
# 5          1       0

# %%
def count_contingency_value(al, start_index = 0, last_index = 1):

    CONTINGENCY_VALUE = {
        "q" : 0,
        "r" : 0,
        "s" : 0,
        "t" : 0,
    }

    column_range = al.shape[1]

    for column in range(column_range):
        for value in CONTINGENCY_TABLE_VALUE:
            item = list((tuple(al.loc[(start_index):(last_index), al.columns[column]]) == CONTINGENCY_TABLE_VALUE[value], value))
            if item[0] == True:
                if item[1] == "q":
                    CONTINGENCY_VALUE["q"] += 1
                if item[1] == "r":
                    CONTINGENCY_VALUE["r"] += 1
                if item[1] == "s":
                    CONTINGENCY_VALUE["s"] += 1
                if item[1] == "t":
                    CONTINGENCY_VALUE["t"] += 1

    return CONTINGENCY_VALUE

# %% [markdown]
# Dissimilarity Binary

# %%
# d(1,2)
dc_1_2 = get_dissimilarity_dataset(al, [1,2], ["lips_thin", "gender"])

# %%
d_e_1_2 = count_contingency_value(dc_1_2, 1, 2)

# %%
# d(1,3)
dc_1_3 = get_dissimilarity_dataset(al, [1,3], ["lips_thin", "gender"])

# %%
d_e_1_3 = count_contingency_value(dc_1_3, 1, 3)

# %%
# d(1,4)
dc_1_4 = get_dissimilarity_dataset(al, [1,4], ["lips_thin", "gender"])

# %%
d_e_1_4 = count_contingency_value(dc_1_4, 1, 4)

# %%
# d(1,5)
dc_1_5 = get_dissimilarity_dataset(al, [1,5], ["lips_thin", "gender"])

# %%
d_e_1_5 = count_contingency_value(dc_1_5, 1, 5)

# %% [markdown]
# jarak

# %%
def measure_dissimilarity_binary_value_assymetric_distance(contingency_value):

    return (contingency_value["r"] + contingency_value["s"]) / (contingency_value["q"] + contingency_value["r"] + contingency_value["s"])

# %%
d_1_2 = measure_dissimilarity_binary_value_assymetric_distance(d_e_1_2)
d_1_3 = measure_dissimilarity_binary_value_assymetric_distance(d_e_1_2)
d_1_4 = measure_dissimilarity_binary_value_assymetric_distance(d_e_1_2)

# %%
d_1_2
# Out:
# 0.5

# %%
d_1_3
# Out:
# 0.5

# %%
d_1_4
# Out:
# 0.5
